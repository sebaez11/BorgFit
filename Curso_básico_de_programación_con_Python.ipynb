# %% [markdown]
# <a href="https://colab.research.google.com/github/sebaez11/BorgFit/blob/main/Curso_b%C3%A1sico_de_programaci%C3%B3n_con_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CURSO BÁSICO DE PROGRAMACIÓN CON PYTHON
# *Platzi Campus REP* 🚀👩‍🚀👨‍🚀💚
# Abel Salas Leal [@AbelSL99](https://twitter.com/AbelSL99) 🐦
#
# Sebastian Baez Ramos
#
# # 1. OPERADORES ARITMETICOS
#
# ### Lo mas sencillo que puedes hacer en python🐍 es usar el lenguaje cómo una calculadora cosas cómo: ➕ sumar, ➖ restar, ✖ multiplicar y ➗ dividir, Se pueden hacer fácilmente en Python con unas cuantas lineas de código.

# %%
5+3
# Out:
# 8

# %%
10-4
# Out:
# 6

# %%
2*7
# Out:
# 14

# %%
42/3
# Out:
# 14.0

# %%
3**2
# Out:
# 9

# %% [markdown]
# # Nota 📝
# ### En Python aplica la jeraquía de operaciones, que quiere decir primero se resuleven parentesís, después exponentes y raíces, después multiplicaciones y divisiones, y por último: sumas y restas.
# ### Asi si tenemos ```3+3*4-8/2``` primero se resolverá ```3*4``` y ```8/2``` lo que nos daría ```3+12-4``` Lo que a su vez es ```11``` ¡Probémoslo en código!

# %%
3+3*4-8/2
# Out:
# 11.0

# %% [markdown]
# ### Sería un error pensar que Python resolverá ```3+3*4-8/2``` de la siguiente forma:
# ###```3+3*4-8/2``` -> ```6*4-8/2``` -> ```24-8/2``` -> ```16/2``` -> ```8``` **¡Error!** 🚧🛑

# %% [markdown]
# ## **Reto 1:** Encuentra la forma de sacar la raiz cuadrada de un número.
#
# ## 💡 Pista: $$\sqrt{x}=x^\frac{1}{2}$$

# %% [markdown]
# # 2. VABRIALES
# ### Una variable se puede representar cómo una caja 📦, y al igual que las cajas sirven para guardar cosas una variable también almacena cosas, o mejor dicho información e información, datos con los cuales nuestros programas podrán trabajar.
#
# ## Esctrutura de una variable: ```Nombre_variable = contenido_valriable``` Al nombre de las variables que en este caso es: ```nombre_variable```, también se le conoce cómo **INDENTIFICADOR** de la variable.

# %%
días_año = 365
mejor_amigo = "Roberto"
tarea_hecha = True

# %% [markdown]
# ## 2.1 Convenciones para nombrar variables
#
# * No usar mayúsculas
# * Remplazar espacios por guiones bajos "_"
# * Descriptivas
# * Evitar acentos y ñ´s
#
# **Protip:** Usar identificadores en inglés
#
# ### Incorrecto nombramiento variables: ```DÍAS_AÑO=356```, ```Dias_Años=365```, ```a="Carlos"```, ```color piñata="Rojo"```. Además, si se llega a usar mayúsculas hay que tener cuidado, pues una variable llamada ```Aprender``` es totalmente diferente de una llamada ```aprender```

# %%
ciudad, estado, pais = "Tampico", "Tamaulipas", "México"
pais
# Out:
# 'México'
